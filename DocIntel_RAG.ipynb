# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan12375/DocIntel-RAG/blob/main/DocIntel_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone the project
# !git clone https://github.com/aryan12375/DocIntel-RAG.git
# %cd DocIntel-RAG

# 2. Install requirements
# !pip install -r requirements.txt
# !npm install -g localtunnel

print("\n✅ Environment Ready!")
# Out:
# Cloning into 'DocIntel-RAG'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 27 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 37.55 KiB | 610.00 KiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/DocIntel-RAG/DocIntel-RAG
# ...
# ⠙⠹⠸⠼⠴⠦
# changed 22 packages in 813ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# ✅ Environment Ready!

# %%
import os
from getpass import getpass

# This keeps your key secret and not saved in the notebook code
os.environ["OPENAI_API_KEY"] = getpass("Paste your OpenAI API Key here: ")

# %%
import urllib
# 1. Print the password for the tunnel
print("STEP 1: Copy this Tunnel Password ->", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())

# 2. Print instructions
print("STEP 2: Click the link below and paste the password to open your dashboard.\n")

# 3. Start the server
# !streamlit run app.py & npx localtunnel --port 8501
